# %%
# First, import yfinance and pandas
import yfinance as yf
import pandas as pd

# Now download GameStop stock data
gme_data = yf.download('GME', start='2010-01-01', end='2025-01-01')

# Reset index
gme_data.reset_index(inplace=True)

# Display first 5 rows
gme_data.head()
# Out:
# /tmp/ipython-input-1691343891.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   gme_data = yf.download('GME', start='2010-01-01', end='2025-01-01')
# [*********************100%***********************]  1 of 1 completed
# Price        Date     Close      High       Low      Open     Volume
# Ticker                  GME       GME       GME       GME        GME
# 0      2010-01-04  3.854644  3.863061  3.703152  3.714934   26702800
# 1      2010-01-05  3.959004  3.996036  3.854643  3.856326   21269600
# 2      2010-01-06  4.044849  4.056632  3.908506  3.948904   21471200
# 3      2010-01-07  3.443929  3.563440  3.268872  3.368183  164761200
# 4      2010-01-08  3.415315  3.573540  3.405215  3.474228   47872400
